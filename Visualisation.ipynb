# %% [markdown]
# # Visualization

# %%
import pandas as pd

from bokeh.charts import Scatter, show
from bokeh.models import Jitter
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="5cde0e59-38bf-48dc-8547-12c0cf99d1d4">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('datasets/bewerkte-datasets/Balbezit Utrecht-NEC.csv')

df = df.set_index('Unnamed: 0')
df.index.name = None

# %%
p = figure( x_range=(0.3,3.7), y_range=(0,4.5), width=437,height=647,title="Eerste doelpunt")

p.image_url(url=['voetbalveld-indeling.png'], x=2, y=2.5, w=2.8, h=4.0, anchor="center")

steps = 5

firstTenX = df.iloc[100-steps:100].x
firstTenY = df.iloc[100-steps:100].y
firstTenBezit = df.iloc[100-steps:100].bezit

for i, x in enumerate(firstTenX):
    y = firstTenY.iloc[i]
    club = 'TEG' if firstTenBezit.iloc[i] == ' TEG' else 'NEC'
    color = 'red' if club == 'TEG' else 'blue'
    p.circle(x={'value': x, 'transform': Jitter(width=0.4)}, y=y, color=color, size=10, legend=club)
    
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="d9e47d78-8c50-4b97-a238-a66fe326ee37"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("d9e47d78-8c50-4b97-a238-a66fe326ee37").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("d9e47d78-8c50-4b97-a238-a66fe326ee37");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'd9e47d78-8c50-4b97-a238-a66fe326ee37' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"f8b2fe77-617d-45fb-b069-553df0628ec6":{"roots":{"references":[{"attributes":{"data_source":{"id":"4c54935f-d15e-4f24-8cbb-03d816e5aaa9","type":"ColumnDataSource"},"glyph":{"id":"f99ce42e-adc5-463f-ad5e-249556e93b0c","type":"ImageURL"},"hover_glyph":null,"nonselection_glyph":{"id":"68070cd8-ab1b-4183-b70b-46c59f993707","type":"ImageURL"},"selection_glyph":null},"id":"744f66ad-158e-44cf-8943-96d42b7f4e1e","type":"GlyphRenderer"},{"attributes":{"dimension":1,"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"},"ticker":{"id":"85483ed9-e561-4dcd-aab0-838b511ee7ab","type":"BasicTicker"}},"id":"840271ac-a9da-4494-997a-42b6de459aed","type":"Grid"},{"attributes":{"data_source":{"id":"02465f79-ff27-4a11-afb3-3c8998e5dd71","type":"ColumnDataSource"},"glyph":{"id":"e0d9ad90-7b32-44ce-96c7-43db70cfac6d","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"0154174c-124d-4032-bc17-169885531aa1","type":"Circle"},"selection_glyph":null},"id":"cd685f6a-55d4-4cd7-b54a-cca4f92d6bc4","type":"GlyphRenderer"},{"attributes":{},"id":"c216953d-2e9c-4d3d-9b79-d546bf2e5aa4","type":"BasicTickFormatter"},{"attributes":{"anchor":"center","h":{"units":"data","value":4.0},"url":{"field":"url"},"w":{"units":"data","value":2.8},"x":{"value":2},"y":{"value":2.5}},"id":"68070cd8-ab1b-4183-b70b-46c59f993707","type":"ImageURL"},{"attributes":{},"id":"280f8b25-488f-4546-ac49-91612f7e4920","type":"BasicTickFormatter"},{"attributes":{"bottom_units":"screen","fill_alpha":{"value":0.5},"fill_color":{"value":"lightgrey"},"left_units":"screen","level":"overlay","line_alpha":{"value":1.0},"line_color":{"value":"black"},"line_dash":[4,4],"line_width":{"value":2},"plot":null,"render_mode":"css","right_units":"screen","top_units":"screen"},"id":"5abfba44-88db-469d-924d-2ceec6fc8d72","type":"BoxAnnotation"},{"attributes":{"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"}},"id":"c2f80ff8-a4a8-4a66-895f-2828cedfbb85","type":"PanTool"},{"attributes":{"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"}},"id":"23ff2315-1d4a-4ee3-8f60-d53fa56e0e15","type":"WheelZoomTool"},{"attributes":{"width":0.4},"id":"2a405c0d-c5a7-4bbc-85ae-d1c452bc9bcc","type":"Jitter"},{"attributes":{"overlay":{"id":"5abfba44-88db-469d-924d-2ceec6fc8d72","type":"BoxAnnotation"},"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"}},"id":"3bf9b49c-aa60-4923-9943-fcbaa10f0aba","type":"BoxZoomTool"},{"attributes":{"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"}},"id":"3f0e284f-03fa-4de0-9140-d11c2e395870","type":"SaveTool"},{"attributes":{"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"}},"id":"5ed78113-85e9-438d-a4bf-3babb7b7b270","type":"ResetTool"},{"attributes":{"plot":null,"text":"Eerste doelpunt"},"id":"bb265618-ee1d-4dba-85ed-e0c2de32496d","type":"Title"},{"attributes":{"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"}},"id":"c774add0-af56-4e1d-b013-096c24a7cf4f","type":"HelpTool"},{"attributes":{},"id":"d41c321d-1aa8-4e5f-b11b-5e97db96a3cb","type":"ToolEvents"},{"attributes":{"formatter":{"id":"c216953d-2e9c-4d3d-9b79-d546bf2e5aa4","type":"BasicTickFormatter"},"plot":{"id":"8fe202a5-dfbf-4928-a5ee-5bd7703edb63","subtype":"Figure","type":"Plot"},"ticker":{"id":"a56a3361-f858-4544-92b3-a1beb6c419aa","type":"BasicTicker"}},"id":"8a69f670-9a29-4cc1-8cc2-db134655bc30","type":"LinearAxis"},{"attributes":{"width":0.4},"id":"16b55a4f-5c77-42c7-86d2-e7f6cd4b5bad","type":"Jitter"},{"attributes":{"width":0.4},"id":"8bbb8141-990a-4cb3-9bd5-f75f520256cd","type":"Jitter"},{"attributes":{},"id":"a56a3361-f858-4544-92b3-a1beb6c419aa","type":"BasicTicker"},{"attributes":{"label":{"value":"TEG"},"renderers":[{"id":"28855147-0825-45c2-a017-206d780445c9","type":"GlyphRenderer"},{"id":"ca15b5a3-276c-46c2-bcb4-cc58f2360d26","type":"GlyphRendere ...
