# %% [markdown]
# # Visualization

# %%
import pandas as pd

from bokeh.charts import Scatter, show
from bokeh.models import Jitter
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="a258b701-57f0-4546-9c42-977cd85dad6b">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('datasets/bewerkte-datasets/Balbezit Utrecht-NEC.csv')

df = df.set_index('Unnamed: 0')
df.index.name = None

# %%
p = figure( x_range=(0.3,3.7), y_range=(0,4.5), width=437,height=647,title="Eerste doelpunt")

p.image_url(url=['voetbalveld-indeling.png'], x=2, y=2.5, w=2.8, h=4.0, anchor="center")

steps = 5

firstTenX = df.iloc[100-steps:100].x
firstTenY = df.iloc[100-steps:100].y
firstTenBezit = df.iloc[100-steps:100].bezit

for i, x in enumerate(firstTenX):
    y = firstTenY.iloc[i]
    club = 'TEG' if firstTenBezit.iloc[i] == ' TEG' else 'NEC'
    color = 'red' if club == 'TEG' else 'blue'
    p.circle(x={'value': x, 'transform': Jitter(width=0.4)}, y=y, color=color, size=10, legend=club)
    
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="280ec4bc-18bd-47e4-b5d7-6c9f55c1ce55"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("280ec4bc-18bd-47e4-b5d7-6c9f55c1ce55").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("280ec4bc-18bd-47e4-b5d7-6c9f55c1ce55");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid '280ec4bc-18bd-47e4-b5d7-6c9f55c1ce55' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"d7f5363b-c3c8-44e3-87e6-a91dc25c1e1c":{"roots":{"references":[{"attributes":{"width":0.4},"id":"81fc78cb-b17e-44db-b23e-3e210d596a61","type":"Jitter"},{"attributes":{"callback":null,"end":3.7,"start":0.3},"id":"9390a3b3-52f1-4907-a14b-4198592bdc59","type":"Range1d"},{"attributes":{"label":{"value":"TEG"},"renderers":[{"id":"13fa907c-d520-4860-80f1-8272c8d5ecd4","type":"GlyphRenderer"},{"id":"6a95437f-aba0-4f0c-bbd2-e455b8948701","type":"GlyphRenderer"},{"id":"1bfc1d44-2453-4681-868a-baad68a7ecc1","type":"GlyphRenderer"},{"id":"b3f5ca78-df88-4e22-9e83-665c8a7a6ca5","type":"GlyphRenderer"},{"id":"0c050b98-7d26-4cf0-a607-942b174f8848","type":"GlyphRenderer"}]},"id":"4224d185-1ccb-4f88-a055-5db978efebaf","type":"LegendItem"},{"attributes":{"data_source":{"id":"9230ee5c-91ab-486e-a777-8aa3462d773f","type":"ColumnDataSource"},"glyph":{"id":"8f96aeb3-090a-445e-b9ce-1d08a4214748","type":"ImageURL"},"hover_glyph":null,"nonselection_glyph":{"id":"712d09f3-5651-4414-8053-5fa6179fe900","type":"ImageURL"},"selection_glyph":null},"id":"54eedcd9-e2c8-4a1e-b89c-1424d697f52f","type":"GlyphRenderer"},{"attributes":{"callback":null},"id":"5e887acc-89db-4b64-b36e-d2f934550ff0","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"81fc78cb-b17e-44db-b23e-3e210d596a61","type":"Jitter"},"value":2},"y":{"value":3}},"id":"f2c47f05-b410-4bc8-88f4-a7ddf078ec26","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"81fc78cb-b17e-44db-b23e-3e210d596a61","type":"Jitter"},"value":2},"y":{"value":3}},"id":"21b7a537-af76-4a8f-98a6-bfc504370596","type":"Circle"},{"attributes":{"data_source":{"id":"5e887acc-89db-4b64-b36e-d2f934550ff0","type":"ColumnDataSource"},"glyph":{"id":"f2c47f05-b410-4bc8-88f4-a7ddf078ec26","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"21b7a537-af76-4a8f-98a6-bfc504370596","type":"Circle"},"selection_glyph":null},"id":"13fa907c-d520-4860-80f1-8272c8d5ecd4","type":"GlyphRenderer"},{"attributes":{"items":[{"id":"4224d185-1ccb-4f88-a055-5db978efebaf","type":"LegendItem"}],"location":"bottom_left","plot":{"id":"85e2d20e-07c5-447b-a029-296ab66d35a5","subtype":"Figure","type":"Plot"}},"id":"11e81a7c-6c8b-4137-bd65-f98dfe6433b3","type":"Legend"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"9f05c346-f705-4836-9f8c-b03d9263c58c","type":"Jitter"},"value":3},"y":{"value":3}},"id":"f7dc82b8-c4e8-4a13-b7cc-8e8ec8062b77","type":"Circle"},{"attributes":{"callback":null},"id":"90653a30-7ec3-4ee6-a721-0d2f54888524","type":"ColumnDataSource"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"9f05c346-f705-4836-9f8c-b03d9263c58c","type":"Jitter"},"value":3},"y":{"value":3}},"id":"6083d13f-505e-4b8c-b88a-172a53a9edeb","type":"Circle"},{"attributes":{"width":0.4},"id":"32cea66f-bfe1-4f7b-a710-8cc7b59d13c0","type":"Jitter"},{"attributes":{"data_source":{"id":"c6f3a7fb-39fb-4e6c-a7f8-9b60e8545885","type":"ColumnDataSource"},"glyph":{"id":"f7dc82b8-c4e8-4a13-b7cc-8e8ec8062b77","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"6083d13f-505e-4b8c-b88a-172a53a9edeb","type":"Circle"},"selection_glyph":null},"id":"6a95437f-aba0-4f0c-bbd2-e455b8948701","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"red"},"line_color":{"value":"red"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"32cea66f-bfe1-4f7b-a710-8cc7b59d13c0","type":"Jitter"},"value":3},"y":{"value":4}},"id":"f8b5df30-932f-4337-98d7-34a9e2356bf9","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1 ...
