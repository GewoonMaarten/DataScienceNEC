# %% [markdown]
# # Visualization

# %%
import pandas as pd

from bokeh.charts import Scatter, show
from bokeh.models import Jitter
from bokeh.plotting import figure, show
from bokeh.io import output_notebook

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="e2dfc01e-099b-4a04-b243-20169fbace47">Loading BokehJS ...</span>
#     </div>

# %%
df = pd.read_csv('datasets/bewerkte-datasets/Balbezit Utrecht-NEC.csv')

df = df.set_index('Unnamed: 0')
df.index.name = None

# %%
p = figure( x_range=(0.3,3.7), y_range=(0,4.5), width=437,height=647,title="Eerste doelpunt")

p.image_url(url=['voetbalveld-indeling.png'], x=2, y=2.5, w=2.8, h=4.0, anchor="center")

steps = 10
doelpuntNummer = 1

goal = df[df['code'].str.contains('Goal')].index.tolist()[doelpuntNummer]

firstTenX = df.iloc[goal-steps:goal].x
firstTenY = df.iloc[goal-steps:goal].y
firstTenBezit = df.iloc[goal-steps:goal].bezit

for i, x in enumerate(firstTenX):
    y = firstTenY.iloc[i]
    club = 'TEG' if firstTenBezit.iloc[i] == ' TEG' else 'NEC'
    color = 'red' if club == 'TEG' else 'blue'
    p.circle(x={'value': x, 'transform': Jitter(width=0.4)}, y=y, color=color, size=10, legend=club)
    
p.legend.location = "bottom_left"
show(p)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id="b6f7b7da-f4de-4fd8-8ccf-a4b4fa3e57c0"></div>
#     </div>
# <script type="text/javascript">
#
#   (function(global) {
#     function now() {
#       return new Date();
#     }
#
#     var force = false;
#
#     if (typeof (window._bokeh_onload_callbacks) === "undefined" || force === true) {
#       window._bokeh_onload_callbacks = [];
#       window._bokeh_is_loading = undefined;
#     }
#
#
#
#     if (typeof (window._bokeh_timeout) === "undefined" || force === true) {
#       window._bokeh_timeout = Date.now() + 0;
#       window._bokeh_failed_load = false;
#     }
#
#     var NB_LOAD_WARNING = {'data': {'text/html':
#        "<div style='background-color: #fdd'>\n"+
#        "<p>\n"+
#        "BokehJS does not appear to have successfully loaded. If loading BokehJS from CDN, this \n"+
#        "may be due to a slow or bad network connection. Possible fixes:\n"+
#        "</p>\n"+
#        "<ul>\n"+
#        "<li>re-rerun `output_notebook()` to attempt to load from CDN again, or</li>\n"+
#        "<li>use INLINE resources instead, as so:</li>\n"+
#        "</ul>\n"+
#        "<code>\n"+
#        "from bokeh.resources import INLINE\n"+
#        "output_notebook(resources=INLINE)\n"+
#        "</code>\n"+
#        "</div>"}};
#
#     function display_loaded() {
#       if (window.Bokeh !== undefined) {
#         document.getElementById("b6f7b7da-f4de-4fd8-8ccf-a4b4fa3e57c0").textContent = "BokehJS successfully loaded.";
#       } else if (Date.now() < window._bokeh_timeout) {
#         setTimeout(display_loaded, 100)
#       }
#     }
#
#     function run_callbacks() {
#       window._bokeh_onload_callbacks.forEach(function(callback) { callback() });
#       delete window._bokeh_onload_callbacks
#       console.info("Bokeh: all callbacks have finished");
#     }
#
#     function load_libs(js_urls, callback) {
#       window._bokeh_onload_callbacks.push(callback);
#       if (window._bokeh_is_loading > 0) {
#         console.log("Bokeh: BokehJS is being loaded, scheduling callback at", now());
#         return null;
#       }
#       if (js_urls == null || js_urls.length === 0) {
#         run_callbacks();
#         return null;
#       }
#       console.log("Bokeh: BokehJS not loaded, scheduling load and callback at", now());
#       window._bokeh_is_loading = js_urls.length;
#       for (var i = 0; i < js_urls.length; i++) {
#         var url = js_urls[i];
#         var s = document.createElement('script');
#         s.src = url;
#         s.async = false;
#         s.onreadystatechange = s.onload = function() {
#           window._bokeh_is_loading--;
#           if (window._bokeh_is_loading === 0) {
#             console.log("Bokeh: all BokehJS libraries loaded");
#             run_callbacks()
#           }
#         };
#         s.onerror = function() {
#           console.warn("failed to load library " + url);
#         };
#         console.log("Bokeh: injecting script tag for BokehJS library: ", url);
#         document.getElementsByTagName("head")[0].appendChild(s);
#       }
#     };var element = document.getElementById("b6f7b7da-f4de-4fd8-8ccf-a4b4fa3e57c0");
#     if (element == null) {
#       console.log("Bokeh: ERROR: autoload.js configured with elementid 'b6f7b7da-f4de-4fd8-8ccf-a4b4fa3e57c0' but no matching script tag was found. ")
#       return false;
#     }
#
#     var js_urls = [];
#
#     var inline_js = [
#       function(Bokeh) {
#         (function() {
#           var fn = function() {
#             var docs_json = {"e6bde18f-2524-481e-a436-8e3329bd135c":{"roots":{"references":[{"attributes":{"callback":null},"id":"cbf0ebf9-d2fb-470b-8ce3-66c5106965b1","type":"ColumnDataSource"},{"attributes":{"callback":null},"id":"dc658162-0bdb-4818-becc-20cbaee16acc","type":"ColumnDataSource"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"04d04ee2-2525-4550-b330-006d8e62e1e0","type":"Jitter"},"value":1},"y":{"value":4}},"id":"ccd8d7ad-3890-43b1-96ca-2e90eff6f7e1","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"04d04ee2-2525-4550-b330-006d8e62e1e0","type":"Jitter"},"value":1},"y":{"value":4}},"id":"3c85ff43-f11e-4f88-97ce-be982aba518c","type":"Circle"},{"attributes":{"data_source":{"id":"dc658162-0bdb-4818-becc-20cbaee16acc","type":"ColumnDataSource"},"glyph":{"id":"ccd8d7ad-3890-43b1-96ca-2e90eff6f7e1","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"3c85ff43-f11e-4f88-97ce-be982aba518c","type":"Circle"},"selection_glyph":null},"id":"220b1d05-3ea7-4dc0-8cb9-cc2468108480","type":"GlyphRenderer"},{"attributes":{"width":0.4},"id":"06900da8-5375-4c0f-bd0e-a14f4a98802d","type":"Jitter"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"06900da8-5375-4c0f-bd0e-a14f4a98802d","type":"Jitter"},"value":2},"y":{"value":4}},"id":"bcb8ae29-76d9-423f-a7bc-acef0ddcbb56","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"06900da8-5375-4c0f-bd0e-a14f4a98802d","type":"Jitter"},"value":2},"y":{"value":4}},"id":"6b742243-e975-4caa-9cd4-c48eabb35a5a","type":"Circle"},{"attributes":{"callback":null},"id":"3819a3d4-1354-4e8e-a520-cd8f29b21b7d","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"cbf0ebf9-d2fb-470b-8ce3-66c5106965b1","type":"ColumnDataSource"},"glyph":{"id":"bcb8ae29-76d9-423f-a7bc-acef0ddcbb56","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"6b742243-e975-4caa-9cd4-c48eabb35a5a","type":"Circle"},"selection_glyph":null},"id":"0d2b164a-d94a-4b3c-be60-6925341a0d78","type":"GlyphRenderer"},{"attributes":{"width":0.4},"id":"b7463f5f-f24a-4880-a7c4-178bd7963b33","type":"Jitter"},{"attributes":{"data_source":{"id":"da9f8c79-8183-4a5d-88e0-6c23de8124dd","type":"ColumnDataSource"},"glyph":{"id":"a51fc75f-61ba-410d-a982-bd5258aab322","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"ddefe450-8138-46e4-b3ce-5636e89ed703","type":"Circle"},"selection_glyph":null},"id":"3db38c8c-ec5d-45e5-8260-6ac0ca909bdc","type":"GlyphRenderer"},{"attributes":{"fill_color":{"value":"blue"},"line_color":{"value":"blue"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"b7463f5f-f24a-4880-a7c4-178bd7963b33","type":"Jitter"},"value":2},"y":{"value":3}},"id":"82c75215-67bc-4056-bbe9-f093a30eb6c0","type":"Circle"},{"attributes":{"fill_alpha":{"value":0.1},"fill_color":{"value":"#1f77b4"},"line_alpha":{"value":0.1},"line_color":{"value":"#1f77b4"},"size":{"units":"screen","value":10},"x":{"transform":{"id":"b7463f5f-f24a-4880-a7c4-178bd7963b33","type":"Jitter"},"value":2},"y":{"value":3}},"id":"cf3a5277-feed-4af8-ae5b-9cc012d4748b","type":"Circle"},{"attributes":{"callback":null},"id":"8b30798d-8f82-4642-b3b1-6742010373ca","type":"ColumnDataSource"},{"attributes":{"data_source":{"id":"3819a3d4-1354-4e8e-a520-cd8f29b21b7d","type":"ColumnDataSource"},"glyph":{"id":"82c75215-67bc-4056-bbe9-f093a30eb6c0","type":"Circle"},"hover_glyph":null,"nonselection_glyph":{"id":"cf3a5277-feed-4af8-ae5b-9cc012d4748b","type":"Circle"},"selection_glyph":null},"id":"67901226-1b48-46de-a6cf-74cb5c72cb75","type":"GlyphRenderer" ...
