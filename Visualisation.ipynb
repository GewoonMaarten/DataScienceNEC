# %% [markdown]
# # Visualization
# In dit notebook zullen we de het passen die tijdens de wedstrijd hebben plaats gevonden. We zullen dit doen met behulp van de python visualization libarary Bokeh. Bokeh leverd hele mooie grafieken op en je kan er interactie aan toevoegen.
# <br />
# <br />
# We importeren een de benodige libraries.

# %%
import pandas as pd

from bokeh.charts import Scatter, show
from bokeh.models import Jitter, CustomJS, ColumnDataSource
from bokeh.plotting import figure, show
from bokeh.io import output_notebook
from bokeh.layouts import widgetbox, row
from bokeh.models.widgets import Dropdown, Slider

output_notebook()
# Out:
#     <div class="bk-root">
#         <a href="http://bokeh.pydata.org" target="_blank" class="bk-logo bk-logo-small bk-logo-notebook"></a>
#         <span id="cbfc9453-88b7-4f94-b342-8e6cd4bd3224">Loading BokehJS ...</span>
#     </div>

# %% [markdown]
# We hebben in het notebook 'Data Collection & Munging' datasets gemaakt gebaseerd op de xml dataset. Deze datasets zullen we hier gebruiken.

# %%
df1 = pd.read_csv('datasets/bewerkte-datasets/Balbezit NEC-Roda.csv')
df2 = pd.read_csv('datasets/bewerkte-datasets/Balbezit NEC-Roda.csv')
df3 = pd.read_csv('datasets/bewerkte-datasets/Balbezit NEC-Roda.csv')
df4 = pd.read_csv('datasets/bewerkte-datasets/Balbezit NEC-Roda.csv')

def set_index(df):
    df = df.set_index('Unnamed: 0')
    df.index.name = None
    return df

df1 = set_index(df1)
df2 = set_index(df2)
df3 = set_index(df3)
df4 = set_index(df4)

# %% [markdown]
# We maken hier het figuur aan. We voegen er een plaatje aan toe als achtergrond. En plotten elke paas als een stipje op het figuur. We kleuren de stipjes rood voor de tegenstander en blauw voor NEC. Dit geeft wat meer overzicht.

# %%
### Plot maken
p = figure( x_range=(0.3,3.7), y_range=(0,4.5), width=437,height=647,title="Doelpunten")

p.image_url(url=['voetbalveld-indeling.png'], x=2, y=2.5, w=2.8, h=4.0, anchor="center")

steps = 1
doelpuntNummer = 1

goal = datasource[datasource['code'].str.contains('Goal')].index.tolist()[doelpuntNummer]

stepsX = datasource.iloc[goal-steps:goal].x
stepsY = datasource.iloc[goal-steps:goal].y
stepBezit = datasource.iloc[goal-steps:goal].bezit

for i, x in enumerate(stepsX):
    y = stepsY.iloc[i]
    club = 'TEG' if stepBezit.iloc[i] == ' TEG' else 'NEC'
    color = 'red' if club == 'TEG' else 'blue'
    p.circle(x={'value': x, 'transform': Jitter(width=0.4)}, y=y, color=color, size=10, legend=club)
    
    
    
### Widgets toevoegen
# Callback
def dropdownCallback(window=None):
    print(cb_obj.get('value'))

# widgets
menu = [("FC utrecht-NEC", "Balbezit Utrecht-NEC.csv"), ("NEC-Roda JC", "Balbezit NEC-Roda.csv"),("PEC_NEC", "Balbezit PEC-NEC.csv"),("NEC-Cambuur", "Balbezit NEC-Cambuur.csv")]
dropdown = Dropdown(label="wedstrijd", menu=menu, callback=CustomJS.from_py_func(dropdownCallback))
slider1 = Slider(start=0, end=4, value=0, step=1, title="Doelpunt nummer:")
slider2 = Slider(start=0, end=10, value=0, step=1, title="Stappen voor doelpunt:")
    
p.legend.location = "bottom_left"

layout = row(p, widgetbox(dropdown, slider1, slider2))
show(layout)
# Out:
#     <div class="bk-root">
#         <div class="bk-plotdiv" id
subtype":"Figure","type":"Plot"},{"attributes":{"plot":{"id":"0fb380bf-0efd-43a1-ba79-403968c31818","subtype":"Figure","type":"Plot"}},"id":"c6559cd5-e9b2-46a1-9cef-7b46efb6f838","type":"HelpTool"},{"attributes":{"callback":null,"end":4,"step":1,"title":"Doelpunt nummer:","value":0},"id":"639302f0-cc88-43f4-976c-b6b6312b85fa","type":"Slider"},{"attributes":{"plot":{"id":"0fb380bf-0efd-43a1-ba79-403968c31818","subtype":"Figure","type":"Plot"}},"id":"4222d5d2-6068-451c-846a-236e72bc84c5","type":"PanTool"},{"attributes":{"children":[{"id":"3892e79f-f87c-4921-ba35-98bdb508029b","type":"Dropdown"},{"id":"639302f0-cc88-43f4-976c-b6b6312b85fa","type":"Slider"},{"id":"59a74d84-6780-43d0-a85b-5c4d081a5de3","type":"Slider"}]},"id":"b92bfca7-4437-404d-8eed-9068863a4d41","type":"WidgetBox"},{"attributes":{"plot":{"id":"0fb380bf-0efd-43a1-ba79-403968c31818","subtype":"Figure","type":"Plot"}},"id":"0af08e31-1f9c-48e7-a74f-b5cdbe6998df","type":"ResetTool"},{"attributes":{"callback":null},"id":"9fe71c86-9f86-426a-8a71-ab85c2251674","type":"ColumnDataSource"},{"attributes":{"children":[{"id":"0fb380bf-0efd-43a1-ba79-403968c31818","subtype":"Figure","type":"Plot"},{"id":"b92bfca7-4437-404d-8eed-9068863a4d41","type":"WidgetBox"}]},"id":"d3a2c768-ecc9-4b06-ad4e-7e3199bc26fb","type":"Row"},{"attributes":{},"id":"b86c21e4-cfca-4404-9410-72253170bacc","type":"BasicTickFormatter"},{"attributes":{"anchor":"center","h":{"units":"data","value":4.0},"url":{"field":"url"},"w":{"units":"data","value":2.8},"x":{"value":2},"y":{"value":2.5}},"id":"abf149ae-538e-496f-a679-f5abd67098d4","type":"ImageURL"},{"attributes":{},"id":"3acf9d9e-3fcc-4fd6-a913-a24c4a6a5a6a","type":"BasicTicker"},{"attributes":{"plot":{"id":"0fb380bf-0efd-43a1-ba79-403968c31818","subtype":"Figure","type":"Plot"},"ticker":{"id":"bb414912-012b-4613-85d4-3fc8dba236ef","type":"BasicTicker"}},"id":"a8136b05-e9b6-4ec0-a5cd-b3e36f61acae","type":"Grid"},{"attributes":{},"id":"f90cf829-641b-4b65-8b58-307554ce0e15","type":"BasicTickFormatter"},{"attributes":{"callback":{"id":"022a5622-569f-4b45-9902-896548348cff","type":"CustomJS"},"icon":null,"label":"wedstrijd","menu":[["FC ut ...
